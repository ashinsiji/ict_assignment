# %% [markdown]
# <a href="https://colab.research.google.com/github/ashinsiji/ict_assignment/blob/main/Assignment03_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/employee.csv')

# %% [markdown]
# 1.Load the dataset given here into the pandas environment and
# identify some basic details of the dataset.

# %%
df.head()
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar   NaN  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9 non-null      object
#  1   age                7 non-null      float64
#  2   income             7 non-null      float64
#  3   gender             7 non-null      object
#  4   department         9 non-null      object
#  5   grade              9 non-null      object
#  6   performance_score  9 non-null      int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 636.0+ bytes

# %%
df.describe()
# Out:
#              age        income  performance_score
# count   7.000000      7.000000           9.000000
# mean   40.428571  52857.142857         610.666667
# std    12.204605  26028.372797         235.671912
# min    23.000000  16000.000000          53.000000
# 25%    31.000000  38500.000000         556.000000
# 50%    45.000000  52000.000000         674.000000
# 75%    49.500000  63500.000000         711.000000
# max    54.000000  98000.000000         901.000000

# %% [markdown]
# 2.Set the column "name" as the index.

# %%
df.set_index('name', inplace=True)
df.head()
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711

# %% [markdown]
# 3.Display employee who has more than 700 performance score.

# %%
display(df[df['performance_score'] > 700])
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# 4.Display employee who has more than 500 and less than 700
# performance score

# %%
display(df[(df['performance_score'] > 500) & (df['performance_score'] < 700)])
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649

# %% [markdown]
# 5.Check and handle missing values in the dataset.

# %%
display(df.isnull().sum())
# Out:
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %% [markdown]
# 6.Check the outliers and handle outliers in performance score using
# Percentiles.

# %%
display(df.head())
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711

# %% [markdown]
# 7.Check the gender column and do one hot encoding.

# %%
if 'gender' in df.columns:
    print('Unique values in the gender column:')
    display(df['gender'].unique())

    df = pd.get_dummies(df, columns=['gender'], prefix='gender')
    print('\nOne-hot encoding completed.')
else:
    print('"gender" column not found. It might already be encoded.')
    print('Current columns:', df.columns.tolist())

display(df.head())
# Out:
# Unique values in the gender column:
# array([nan, 'F', 'M'], dtype=object)
# One-hot encoding completed.
#                 age   income  department grade  performance_score  gender_F  \
# name
# Allen Smith    45.0      NaN  Operations    G3                723     False
# S Kumar         NaN  16000.0     Finance    G0                520      True
# Jack Morgan    32.0  35000.0     Finance    G2                674     False
# Ying Chin      45.0  65000.0       Sales    G3                556      True
# Dheeraj Patel  30.0  42000.0  Operations    G2                711      True
#
#                gender_M
# name
# Allen Smith       False
# S Kumar           False
# Jack Morgan        True
# Ying Chin         False
# Dheeraj Patel     False
